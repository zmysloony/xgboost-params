# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sn

# %%
temp = [[0.5,0],[0.5985291742175212, 0.631174453003041],[0.6045291742175212, 48.02890743800526],[0.6088673396409873, 48.65143737800099],[0.6109690861079872, 51.43027099100436],[0.6113648677147953, 57.55137946200557],[0.6114616826334154, 60.60240565400454]]

muta_05 = pd.DataFrame.from_records(temp, columns=['metric', 'time'])

muta_05['type']= 'muta 50%'

muta_05
# Out:
#      metric       time      type
# 0  0.500000   0.000000  muta 50%
# 1  0.598529   0.631174  muta 50%
# 2  0.604529  48.028907  muta 50%
# 3  0.608867  48.651437  muta 50%
# 4  0.610969  51.430271  muta 50%
# 5  0.611365  57.551379  muta 50%
# 6  0.611462  60.602406  muta 50%

# %%
temp = [[0.5,0],[0.5979169677959254, 9.897356768000463],[0.6061755959159032, 62.734235789001104],[0.6099270160894583, 121.10066660300072],[0.6152558787112192, 176.84386561500287]]

hill_05 = pd.DataFrame.from_records(temp, columns=['metric', 'time'])

hill_05['type']= 'hill 50%'

hill_05
# Out:
#      metric        time      type
# 0  0.500000    0.000000  hill 50%
# 1  0.597917    9.897357  hill 50%
# 2  0.606176   62.734236  hill 50%
# 3  0.609927  121.100667  hill 50%
# 4  0.615256  176.843866  hill 50%

# %%
temp = [[0.5,0],[0.5985291742175212, 0.6312241089981399],[0.6045291742175212, 1.2650885969997034],[0.6088673396409873, 48.74520659299742],[0.6109690861079872, 49.38523801299743],[0.6109690861079872, 50.010195754999586],[0.6109690861079872, 50.63475725900207],[0.6113648677147953, 52.18585431700194],[0.6113648677147953, 53.25897549500223],[0.6113648677147953, 54.33116841300216],[0.6113648677147953, 55.413078382000094],[0.6113648677147953, 56.49514066900156],[0.6114616826334154, 58.34651249599847],[0.6114616826334154, 59.890063332000864],[0.6152558787112192, 61.415853395999875],[0.6152558787112192, 62.18835315800243],[0.6152558787112192, 65.54836031000013],[0.6152558787112192, 66.47051993700006],[0.6152558787112192, 69.2349086969989],[0.6152558787112192, 72.95513350200054],[0.6152558787112192, 188.669674210003],[0.6152558787112192, 189.43325536300108],[0.6152558787112192, 190.1965765049972],[0.6152558787112192, 190.95970052399935],[0.6152558787112192, 198.58180067899957],[0.6152558787112192, 206.0616083549976],[0.6152558787112192, 212.5669024250019],[0.6152558787112192, 230.36968313300167],[0.6152558787112192, 235.31643823599734],[0.6152558787112192, 239.07252639000217],[0.6152558787112192, 240.9062324070037],[0.6152558787112192, 241.82475156599685],[0.6152558787112192, 245.5624715419981],[0.6152558787112192, 305.4706589580019],[0.6152558787112192, 338.81031470699963],[0.6152558787112192, 340.70015068499924],[0.6152558787112192, 341.9382500790016],[0.6152558787112192, 345.5118875729968],[0.6152558787112192, 352.5916566520027],[0.6152558787112192, 360.2646174170004],[0.6152558787112192, 362.1414093589992],[0.6152558787112192, 370.2003747620038],[0.6152558787112192, 371.12613017299736],[0.6152558787112192, 372.0476962890025],[0.6152558787112192, 377.81626171000244],[0.6152558787112192, 388.7086687370029],[0.6152558787112192, 391.77677550200315],[0.6152558787112192, 392.5526447290031],[0.6152558787112192, 397.482147515002]]

muta_005 = pd.DataFrame.from_records(temp, columns=['metric', 'time'])

muta_005['type']= 'muta 5%'

muta_005
# Out:
#       metric        time     type
# 0   0.500000    0.000000  muta 5%
# 1   0.598529    0.631224  muta 5%
# 2   0.604529    1.265089  muta 5%
# 3   0.608867   48.745207  muta 5%
# 4   0.610969   49.385238  muta 5%
# 5   0.610969   50.010196  muta 5%
# 6   0.610969   50.634757  muta 5%
# 7   0.611365   52.185854  muta 5%
# 8   0.611365   53.258975  muta 5%
# 9   0.611365   54.331168  muta 5%
# 10  0.611365   55.413078  muta 5%
# 11  0.611365   56.495141  muta 5%
# 12  0.611462   58.346512  muta 5%
# 13  0.611462   59.890063  muta 5%
# 14  0.615256   61.415853  muta 5%
# 15  0.615256   62.188353  muta 5%
# 16  0.615256   65.548360  muta 5%
# 17  0.615256   66.470520  muta 5%
# 18  0.615256   69.234909  muta 5%
# 19  0.615256   72.955134  muta 5%
# 20  0.615256  188.669674  muta 5%
# 21  0.615256  189.433255  muta 5%
# 22  0.615256  190.196577  muta 5%
# 23  0.615256  190.959701  muta 5%
# 24  0.615256  198.581801  muta 5%
# 25  0.615256  206.061608  muta 5%
# ...

# %%
temp = [[0.5,0],[0.6057176212410019, 5.27875559599488],[0.6084998478992606, 24.594645299999684],[0.6093763326268272, 43.695302037995134],[0.6145011462875402, 61.56858385099622],[0.6152558787112192, 78.2539417109947]]

hill_005 = pd.DataFrame.from_records(temp, columns=['metric', 'time'])

hill_005['type']= 'hill 5%'

hill_005
# Out:
#      metric       time     type
# 0  0.500000   0.000000  hill 5%
# 1  0.605718   5.278756  hill 5%
# 2  0.608500  24.594645  hill 5%
# 3  0.609376  43.695302  hill 5%
# 4  0.614501  61.568584  hill 5%
# 5  0.615256  78.253942  hill 5%

# %%
wykres_5 = hill_005

wykres_5 = wykres_5.append(muta_005)

wykres_5
# Out:
#       metric        time     type
# 0   0.500000    0.000000  hill 5%
# 1   0.605718    5.278756  hill 5%
# 2   0.608500   24.594645  hill 5%
# 3   0.609376   43.695302  hill 5%
# 4   0.614501   61.568584  hill 5%
# 5   0.615256   78.253942  hill 5%
# 0   0.500000    0.000000  muta 5%
# 1   0.598529    0.631224  muta 5%
# 2   0.604529    1.265089  muta 5%
# 3   0.608867   48.745207  muta 5%
# 4   0.610969   49.385238  muta 5%
# 5   0.610969   50.010196  muta 5%
# 6   0.610969   50.634757  muta 5%
# 7   0.611365   52.185854  muta 5%
# 8   0.611365   53.258975  muta 5%
# 9   0.611365   54.331168  muta 5%
# 10  0.611365   55.413078  muta 5%
# 11  0.611365   56.495141  muta 5%
# 12  0.611462   58.346512  muta 5%
# 13  0.611462   59.890063  muta 5%
# 14  0.615256   61.415853  muta 5%
# 15  0.615256   62.188353  muta 5%
# 16  0.615256   65.548360  muta 5%
# 17  0.615256   66.470520  muta 5%
# 18  0.615256   69.234909  muta 5%
# 19  0.615256   72.955134  muta 5%
# ...

# %%
sn.relplot(x='time',y='metric', hue="type", style="type", data=wykres_5)

# %%
wykres_5_2 = wykres_5[wykres_5.time < 70]

wykres_5_2
# Out:
#       metric       time     type
# 0   0.500000   0.000000  hill 5%
# 1   0.605718   5.278756  hill 5%
# 2   0.608500  24.594645  hill 5%
# 3   0.609376  43.695302  hill 5%
# 4   0.614501  61.568584  hill 5%
# 0   0.500000   0.000000  muta 5%
# 1   0.598529   0.631224  muta 5%
# 2   0.604529   1.265089  muta 5%
# 3   0.608867  48.745207  muta 5%
# 4   0.610969  49.385238  muta 5%
# 5   0.610969  50.010196  muta 5%
# 6   0.610969  50.634757  muta 5%
# 7   0.611365  52.185854  muta 5%
# 8   0.611365  53.258975  muta 5%
# 9   0.611365  54.331168  muta 5%
# 10  0.611365  55.413078  muta 5%
# 11  0.611365  56.495141  muta 5%
# 12  0.611462  58.346512  muta 5%
# 13  0.611462  59.890063  muta 5%
# 14  0.615256  61.415853  muta 5%
# 15  0.615256  62.188353  muta 5%
# 16  0.615256  65.548360  muta 5%
# 17  0.615256  66.470520  muta 5%
# 18  0.615256  69.234909  muta 5%

# %%
sn.relplot(x='time',y='metric', hue="type", style="type", data=wykres_5_2)

# %%
wykres_50 = hill_05

wykres_50 = wykres_50.append(muta_05)

wykres_50
# Out:
#      metric        time      type
# 0  0.500000    0.000000  hill 50%
# 1  0.597917    9.897357  hill 50%
# 2  0.606176   62.734236  hill 50%
# 3  0.609927  121.100667  hill 50%
# 4  0.615256  176.843866  hill 50%
# 0  0.500000    0.000000  muta 50%
# 1  0.598529    0.631174  muta 50%
# 2  0.604529   48.028907  muta 50%
# 3  0.608867   48.651437  muta 50%
# 4  0.610969   51.430271  muta 50%
# 5  0.611365   57.551379  muta 50%
# 6  0.611462   60.602406  muta 50%

# %%
sn.relplot(x='time',y='metric', hue="type", style="type", data=wykres_50)

# %%
wykres_50_2 = wykres_50[wykres_50.time < 70]

wykres_50_2
# Out:
#      metric       time      type
# 0  0.500000   0.000000  hill 50%
# 1  0.597917   9.897357  hill 50%
# 2  0.606176  62.734236  hill 50%
# 0  0.500000   0.000000  muta 50%
# 1  0.598529   0.631174  muta 50%
# 2  0.604529  48.028907  muta 50%
# 3  0.608867  48.651437  muta 50%
# 4  0.610969  51.430271  muta 50%
# 5  0.611365  57.551379  muta 50%
# 6  0.611462  60.602406  muta 50%

# %%
sn.relplot(x='time',y='metric', hue="type", style="type", data=wykres_50_2)
